# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\worldcitiespop.csv")
# Out:
# C:\Users\itole\AppData\Local\Temp\ipykernel_77960\3803636654.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\itole\Downloads\worldcitiespop.csv")

# %%
df.dropna(how="any")
# Out:
#         Country              City        AccentCity Region  Population  \
# 6            ad  andorra la vella  Andorra la Vella    7.0     20430.0
# 20           ad           canillo           Canillo    2.0      3292.0
# 32           ad            encamp            Encamp    3.0     11224.0
# 49           ad        la massana        La Massana    4.0      7211.0
# 53           ad      les escaldes      Les Escaldes    8.0     15854.0
# ...         ...               ...               ...    ...         ...
# 3173646      zw         redcliffe         Redcliffe      6     38231.0
# 3173676      zw            rusape            Rusape      4     23761.0
# 3173737      zw          shurugwi          Shurugwi      7     17107.0
# 3173892      zw    victoria falls    Victoria Falls      0     36702.0
# 3173957      zw        zvishavane        Zvishavane      7     79876.0
#
#           Latitude  Longitude
# 6        42.500000   1.516667
# 20       42.566667   1.600000
# ...

# %%
filtered_df = df[df['Population'] > 1000]

# %%
filtered_df
# Out:
#         Country              City        AccentCity Region  Population  \
# 6            ad  andorra la vella  Andorra la Vella    7.0     20430.0
# 20           ad           canillo           Canillo    2.0      3292.0
# 32           ad            encamp            Encamp    3.0     11224.0
# 49           ad        la massana        La Massana    4.0      7211.0
# 53           ad      les escaldes      Les Escaldes    8.0     15854.0
# ...         ...               ...               ...    ...         ...
# 3173646      zw         redcliffe         Redcliffe      6     38231.0
# 3173676      zw            rusape            Rusape      4     23761.0
# 3173737      zw          shurugwi          Shurugwi      7     17107.0
# 3173892      zw    victoria falls    Victoria Falls      0     36702.0
# 3173957      zw        zvishavane        Zvishavane      7     79876.0
#
#           Latitude  Longitude
# 6        42.500000   1.516667
# 20       42.566667   1.600000
# ...

# %%
filtered_df.to_csv(r"C:\worldcitiespop2.csv", index=False)
